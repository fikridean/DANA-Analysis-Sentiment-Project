# %%
# %pip install google-play-scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
scrapreview = reviews(
    'id.dana',          
    lang='en',             
    country='id',          
    sort=Sort.MOST_RELEVANT,
    count=10000             
)

# %%
scrapreview[0]
# Out:
# [{'reviewId': '6e12324d-a24e-4e2f-aac3-e65f19cf7d53',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "Worst e-money app I ever used, making every online payments complicated and difficult. Every time I want to make a transaction, I have to wait about 30 seconds, supposedly for security verification. But then, it says payment failed. Tried several times, still failed. Even though my signal is fine, and using another e-money apps is smooth. It's just this app that's a bit different.",
#   'score': 1,
#   'thumbsUpCount': 96,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 22, 8, 15, 55),
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame([review for review in scrapreview[0]])

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  6e12324d-a24e-4e2f-aac3-e65f19cf7d53  A Google user
# 1  9fa385b7-4557-4f24-9bd4-c0ba76cf204e  A Google user
# 2  fe58b850-3ac3-430c-b279-4a77aace8bf5  A Google user
# 3  d9dff1d0-f6ac-4604-b1fb-8901543e7982  A Google user
# 4  1f9f977b-695b-4e1d-8fb3-33e9fdec34fe  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Worst e-money app I ever used, making every on...      1             96
# 1  TERRIBLE! I've spent 30 minute to do a simple ...      1            901
# 2  It used to be a great app, but recently I can'...      1           1149
# ...

# %%
df = df.drop_duplicates()
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6108 entries, 1 to 9999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              6108 non-null   object
#  1   userName              6108 non-null   object
#  2   userImage             6108 non-null   object
#  3   content               6108 non-null   object
#  4   score                 6108 non-null   int64
#  5   thumbsUpCount         6108 non-null   int64
#  6   reviewCreatedVersion  6108 non-null   object
#  7   at                    6108 non-null   datetime64[ns]
#  8   replyContent          6108 non-null   object
#  9   repliedAt             6108 non-null   datetime64[ns]
#  10  appVersion            6108 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 572.6+ KB

# %%
new_df = df.drop(['userName', 'userImage', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt', 'appVersion'], axis=1)

# %%
new_df.head()
# Out:
#                                reviewId  \
# 1  9fa385b7-4557-4f24-9bd4-c0ba76cf204e
# 2  fe58b850-3ac3-430c-b279-4a77aace8bf5
# 3  d9dff1d0-f6ac-4604-b1fb-8901543e7982
# 4  1f9f977b-695b-4e1d-8fb3-33e9fdec34fe
# 5  21177be8-5e8a-4af7-b1a4-109227d431a3
#
#                                              content  score  thumbsUpCount
# 1  TERRIBLE! I've spent 30 minute to do a simple ...      1            901
# 2  It used to be a great app, but recently I can'...      1           1149
# 3  The most terrible experience I've ever got sin...      1            497
# 4  Bad system. The promotion of cashback doesnt g...      1            584
# 5  on 0.4.2 version (android), the app always cra...      1            107

# %%
new_df.to_csv('ulasan_aplikasi.csv', index=False)

# %%
# %pip freeze > requirements_2.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
